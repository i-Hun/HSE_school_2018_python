# %% [markdown]
# 1. Load file wine_reviews.csv using [`read_csv` function](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html). This file contains the wine reviews dataset, consisting of wine varieties, vineyards, country and review text.
# 2. How many rows and columns are in the table? (HINT: use [`shape`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) property)
# 3. How many missing values they have? (HINT: use [`isnull`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isnull.html) and [`sum`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html))
# 4. What wines are rated higher? (HINT: `sort_values(ascending=False)`)
# 5. How many wines from France has a more points than averege?
# 5. Wines of what `province` are the most expensive ones? (HINT: we didn't learn how to do such things, so just write this line of code: `wine.groupby("province")["price"].mean().sort_values(ascending=False)`. I just wanted to show you how group data with `groupby` 😁)
# 6. Is there a correlation between `points` and `price`?
# 7. Draw a regression plot with `points` and `price` using `regplot` function of `seaborn`.
# 8. Create two new series `points_log` and `price_log` that will store logarithm of `points` and `price` respectively. (HINT: use [`np.log()`](https://docs.scipy.org/doc/numpy/reference/generated/numpy.log.html) function to create these variables). Create `regplot`. Is the distrubution has become more normal?
# 7. Build a linear regression model with `points_log` as dependent variable and `price_log` as independent one. What is the $R^2$? Beta coefficient?
# 8. How would you interpet the results of this linear regression?
# 9. Run some diagnostics to test for normality of the residuals snd heteroskedasticity. Is there any problem?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
from statsmodels.compat import lzip

# %%
df = pd.read_csv("wine_reviews.csv")

# %%
sns.jointplot(x="price", y="points", data=df, kind="reg")

# %%
df["points_log"] = np.log(df["points"])
df["price_log"] = np.log(df["price"])

# %%
sns.jointplot(x="price_log", y="points_log", data=df, kind="reg")
